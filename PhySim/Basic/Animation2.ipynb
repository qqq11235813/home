# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

pause = False
def simData():
    t_max = 10.0
    dt = 0.05
    x = 0.0
    t = 0.0
    while t < t_max:
        if not pause:
            x=np.arange(0.0,2.0,0.01)
            y = np.sin(1*np.pi*(x-0.05*t))-np.sin(0.5*np.pi*(x-0.1*t))
            z = np.sin(0.5*np.pi*(x-0.1*t))

            t = t + dt

        yield x, y, z

def onClick(event):
    global pause
    pause ^= True

def simPoints(simData):
    if not pause:
        x, y, z= simData[0], simData[1],simData[2]
        line1.set_data(x, y)
        line2.set_data(x,z)
        return line1,line2 
    else:
        x, y, z= simData[0], simData[1],simData[2]
        line1.set_data(x, y)
        return line1

fig = plt.figure()
ax = fig.add_subplot(111)
line1, = ax.plot([], [])
line2,=ax.plot([],[])
ax.set_ylim(-1, 1)
ax.set_xlim(0, 2)

fig.canvas.mpl_connect('button_press_event', onClick)

ani = animation.FuncAnimation(fig, simPoints, simData, blit=False,interval=20,
    repeat=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

pause = False
def simData():
    t_max = 10.0
    dt = 0.05
    x = 0.0
    t = 0.0
    while t < t_max:
        if not pause:
            line1, = ax.plot([], [])
            line2,=ax.plot([],[],alpha=0.7)
            x=np.arange(0.0,2.0,0.01)
            y = np.sin(1*np.pi*(x-0.05*t))-np.sin(0.5*np.pi*(x-0.1*t))
            z = np.sin(0.5*np.pi*(x-0.1*t))

            t = t + dt
            
        yield x, y, z

def onClick(event):
    global pause
    pause ^= True

def simPoints(simData):
    x, y, z,pause= simData[0], simData[1],simData[2],simData[2]
    line1.set_data(x, y)
    line2.set_data(x,z)
    return line1,line2 
   
fig = plt.figure()
ax = fig.add_subplot(111)
line1, = ax.plot([], [])
line2,=ax.plot([],[])
ax.set_ylim(-1, 1)
ax.set_xlim(0, 2)

fig.canvas.mpl_connect('button_press_event', onClick)

ani = animation.FuncAnimation(fig, simPoints, simData, blit=False,interval=20,
    repeat=True)

plt.show()

# %%
"""
========================================
An animated image using a list of images
========================================

This examples demonstrates how to animate an image from a list of images (or
Artists).
"""
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig = plt.figure()

pause = False
def onClick(event):
    global pause
    pause ^= True


def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)
# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(60):
    x += np.pi / 15.
    y += np.pi / 20.
    im = plt.imshow(f(x, y), animated=True)
    ims.append([im])

if not pause:
    ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)
    
else:
    ani.new_frame_seq()
    ani = animation.ArtistAnimation(fig, ims, interval=150, blit=True,
                                repeat_delay=1000)
    
# ani.save('dynamic_images.mp4')

plt.show()
