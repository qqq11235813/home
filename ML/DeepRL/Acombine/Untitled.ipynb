# %%
import numpy as np
import tensorflow as tf
import gym

# %%
def learning(environment = 'CartPole-v0', episode = 20, max_step = 100):
    env = gym.make(environment)
    print(env.action_space)
    print(env.observation_space)
    for i_episode in range(episode):
        observation = env.reset()
        for t in range(max_step):
            env.render()
            action = env.action_space.sample()
            observation, reward, done, info = env.step(action)
            print(action)
            print(observation)
            if done:
                print("Finished after {} steps".format(t+1))
                break
learning(environment = "SpaceInvaders-v0")
# Out:
# [2017-12-14 10:48:21,145] Making new env: SpaceInvaders-v0
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-fdc44b800de7> in <module>()
#      14                 print("Finished after {} steps".format(t+1))
#      15                 break
# ---> 16 learning(environment = "SpaceInvaders-v0")
#
# <ipython-input-2-fdc44b800de7> in learning(environment, episode, max_step)
#       1 def learning(environment = 'CartPole-v0', episode = 20, max_step = 100):
# ----> 2     env = gym.make(environment)
#       3     print(env.action_space)
#       4     print(env.observation_space)
#       5     for i_episode in range(episode):
#
# /home/frank/gym/gym/envs/registration.py in make(id)
#     162
#     163 def make(id):
# --> 164     return registry.make(id)
#     165
#     166 def spec(id):
#
# /home/frank/gym/gym/envs/registration.py in make(self, id)
#     120         logger.info('Making new env: %s', id)
#     121         spec = self.spec(id)
# --> 122         env = spec.make()
#     123         if (env.spec.timestep_limit is not None) and not spec.tags.get('vnc'):
#     124             from gym.wrappers.time_limit import TimeLimit
#
# /home/frank/gym/gym/envs/registration.py in make(self)
#      86             env = self._entry_point()
#      87         else:
# ---> 88             cls = load(self._entry_point)
#      89             env = cls(**self._kwargs)
#      90
#
# /home/frank/gym/gym/envs/registration.py in load(name)
#      15 def load(name):
#      16     entry_point = pkg_resources.EntryPoint.parse('x={}'.format(name))
# ---> 17     result = entry_point.load(False)
#      18     return result
#      19
#
# /usr/local/lib/python3.5/dist-packages/pkg_resources/__init__.py in load(self, require, *args, **kwargs)
#    2400         if require:
#    2401             self.require(*args, **kwargs)
# -> 2402         return self.resolve()
#    2403
#    2404     def resolve(self):
#
# /usr/local/lib/python3.5/dist-packages/pkg_resources/__init__.py in resolve(self)
#    2406         Resolve the entry point from its module and attrs.
#    2407         """
# -> 2408         module = __import__(self.module_name, fromlist=['__name__'], level=0)
#    2409         try:
#    2410             return functools.reduce(getattr, self.attrs, module)
#
# /home/frank/gym/gym/envs/atari/__init__.py in <module>()
# ----> 1 from gym.envs.atari.atari_env import AtariEnv
#
# /home/frank/gym/gym/envs/atari/atari_env.py in <module>()
#       7
#       8 try:
# ----> 9     import atari_py
#      10 except ImportError as e:
#      11     raise error.DependencyNotInstalled("{}. (HINT: you can install Atari dependencies by running 'pip install gym[atari]'.)".format(e))
#
# /usr/local/lib/python3.5/dist-packages/atari_py-0.1.1-py3.5.egg/atari_py/__init__.py in <module>()
# ----> 1 from .ale_python_interface import *
#       2 import os
#       3
#       4 def _game_dir():
#       5     return os.path.join(os.path.abspath(os.path.dirname(__file__)), "atari_roms")
#
# /usr/local/lib/python3.5/dist-packages/atari_py-0.1.1-py3.5.egg/atari_py/ale_python_interface.py in <module>()
#      12
#      13 ale_lib = cdll.LoadLibrary(os.path.join(os.path.dirname(__file__),
# ---> 14                                         'ale_interface/build/libale_c.so'))
#      15
#      16 ale_lib.ALE_new.argtypes = None
#
# /usr/lib/python3.5/ctypes/__init__.py in LoadLibrary(self, name)
#     423
#     424     def LoadLibrary(self, name):
# --> 425         return self._dlltype(name)
#     426
#     427 cdll = LibraryLoader(CDLL)
#
# /usr/lib/python3.5/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     345
#     346         if handle is None:
# --> 347             self._handle = _dlopen(self._name, mode)
#     348         else:
#     349             self._handle = handle
#
# OSError: /usr/local/lib/python3.5/dist-packages/atari_py-0.1.1-py3.5.egg/atari_py/ale_interface/build/libale_c.so: cannot open shared object file: No such file or directory

# %%
import gym
env = gym.make('SpaceInvaders-v0')
env.reset()
env.render()
# Out:
# [2017-12-14 10:48:26,664] Making new env: SpaceInvaders-v0
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-934e95aaec4b> in <module>()
#       1 import gym
# ----> 2 env = gym.make('SpaceInvaders-v0')
#       3 env.reset()
#       4 env.render()
#
# /home/frank/gym/gym/envs/registration.py in make(id)
#     162
#     163 def make(id):
# --> 164     return registry.make(id)
#     165
#     166 def spec(id):
#
# /home/frank/gym/gym/envs/registration.py in make(self, id)
#     120         logger.info('Making new env: %s', id)
#     121         spec = self.spec(id)
# --> 122         env = spec.make()
#     123         if (env.spec.timestep_limit is not None) and not spec.tags.get('vnc'):
#     124             from gym.wrappers.time_limit import TimeLimit
#
# /home/frank/gym/gym/envs/registration.py in make(self)
#      86             env = self._entry_point()
#      87         else:
# ---> 88             cls = load(self._entry_point)
#      89             env = cls(**self._kwargs)
#      90
#
# /home/frank/gym/gym/envs/registration.py in load(name)
#      15 def load(name):
#      16     entry_point = pkg_resources.EntryPoint.parse('x={}'.format(name))
# ---> 17     result = entry_point.load(False)
#      18     return result
#      19
#
# /usr/local/lib/python3.5/dist-packages/pkg_resources/__init__.py in load(self, require, *args, **kwargs)
#    2400         if require:
#    2401             self.require(*args, **kwargs)
# -> 2402         return self.resolve()
#    2403
#    2404     def resolve(self):
#
# /usr/local/lib/python3.5/dist-packages/pkg_resources/__init__.py in resolve(self)
#    2406         Resolve the entry point from its module and attrs.
#    2407         """
# -> 2408         module = __import__(self.module_name, fromlist=['__name__'], level=0)
#    2409         try:
#    2410             return functools.reduce(getattr, self.attrs, module)
#
# /home/frank/gym/gym/envs/atari/__init__.py in <module>()
# ----> 1 from gym.envs.atari.atari_env import AtariEnv
#
# /home/frank/gym/gym/envs/atari/atari_env.py in <module>()
#       7
#       8 try:
# ----> 9     import atari_py
#      10 except ImportError as e:
#      11     raise error.DependencyNotInstalled("{}. (HINT: you can install Atari dependencies by running 'pip install gym[atari]'.)".format(e))
#
# /usr/local/lib/python3.5/dist-packages/atari_py-0.1.1-py3.5.egg/atari_py/__init__.py in <module>()
# ----> 1 from .ale_python_interface import *
#       2 import os
#       3
#       4 def _game_dir():
#       5     return os.path.join(os.path.abspath(os.path.dirname(__file__)), "atari_roms")
#
# /usr/local/lib/python3.5/dist-packages/atari_py-0.1.1-py3.5.egg/atari_py/ale_python_interface.py in <module>()
#      12
#      13 ale_lib = cdll.LoadLibrary(os.path.join(os.path.dirname(__file__),
# ---> 14                                         'ale_interface/build/libale_c.so'))
#      15
#      16 ale_lib.ALE_new.argtypes = None
#
# /usr/lib/python3.5/ctypes/__init__.py in LoadLibrary(self, name)
#     423
#     424     def LoadLibrary(self, name):
# --> 425         return self._dlltype(name)
#     426
#     427 cdll = LibraryLoader(CDLL)
#
# /usr/lib/python3.5/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     345
#     346         if handle is None:
# --> 347             self._handle = _dlopen(self._name, mode)
#     348         else:
#     349             self._handle = handle
#
# OSError: /usr/local/lib/python3.5/dist-packages/atari_py-0.1.1-py3.5.egg/atari_py/ale_interface/build/libale_c.so: cannot open shared object file: No such file or directory
